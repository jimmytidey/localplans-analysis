# %%
from helpers import pdf_to_text
import os


# this no longer works
pdfs = os.listdir("saved_local_plan_pdfs")
pdfs = sorted(pdfs)

for pdf in pdfs:
    pdf_to_text("saved_local_plan_pdfs", "saved_local_plans_txts", pdf)
# Out:
# FAIL******
# .DS_Store
# FAIL******
# Adur_District_Council.pdf
# FAIL******
# Allerdale_Borough_Council.pdf
# FAIL******
# Amber_Valley_Borough_Council.pdf
# FAIL******
# Arun_District_Council.pdf
# FAIL******
# Ashfield_District_Council.pdf
# FAIL******
# Ashford_Borough_Council.pdf
# FAIL******
# Babergh_District_Council.pdf
# FAIL******
# Barnsley_Metropolitan_Borough_Council.pdf
# FAIL******
# Barrow-in-Furness_Borough_Council.pdf
# FAIL******
# Basildon_Borough_Council.pdf
# FAIL******
# Bassetlaw_District_Council.pdf
# FAIL******
# Bath_and_North_East_Somerset_Council.pdf
# FAIL******
# Bedford_Borough_Council.pdf
# FAIL******
# Birmingham_City_Council.pdf
# FAIL******
# Blaby_District_Council.pdf
# FAIL******
# Blackburn_with_Darwen_Borough_Council.pdf
# FAIL******
# Blackpool_Borough_Council.pdf
# FAIL******
# Bolsover_District_Council.pdf
# FAIL******
# Bolton_Metropolitan_Borough_Council.pdf
# FAIL******
# Borough_Council_of_King's_Lynn_and_West_Norfolk.pdf
# FAIL******
# ...

# %%
# Out:
# FAIL******
# MD3081 Appendix B - RDBR OAPF Engagement Report.pdf
